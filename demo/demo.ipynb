# %% [markdown]
# # 1. APS(advanced planning and scheduling) 高级计划与排程
#
# ## demand 需求
# - Continuous Process Manufacturing 连续流程制造
# - Discrete Manufacturing 离散制造
#
# ## problems
# ### (Job) Shop Scheduling Problem(JSSP) 车间调度问题
# ### Resource-Constrained Project Scheduling Problem(RCPSP) 资源受限项目调度问题
# ### Makespan Minimization Problem(MMP) 最小化完工时间问题
# ### Total Weighted Tardiness Problem(TWTP) 总加权延迟问题
# ### Minimizing Other Objectives(e.g cost, energy, etc.) 最小化其他目标（例如成本、能源等）
#
# ## places need algorithms 需要算法的地方
# Noticing these are all NP-hard problems, we need to use heuristic algorithms to solve large-scale problems(e.g. 6 machines, 12 jobs a MIP only need 60s, but 20 jobs needs hours to solve).
# 注意到这些都是 NP-hard 问题，我们需要使用启发式算法来解决大规模问题（例如 6 台机器，12 个工作MIP只需要60多秒，但是增加到20个工作就需要几个小时去求解）。
#
# ### production planning (Forecasting) 生产计划（预测）
# - ARIMA(autoregressive integrated moving average) 自回归积分滑动平均模型
#   - SARIMA(seasonal autoregressive integrated moving average) 季节性自回归积分滑动平均模型
#   - ARIMAX(autoregressive integrated moving average with exogenous variables) 带外生变量的自回归积分滑动平均模型
# - ETS(exponential smoothing) 指数平滑
#   <!-- - ETSX(error, trend, seasonality with exogenous variables) -->
#   <!-- - 带外生变量的误差、趋势、季节性模型 -->
# - Neural Network 神经网络
#   - MLP(multi-layer perceptron) 多层感知器
#   - LSTM(long short-term memory) 长短期记忆
# - Random Forest 随机森林
#
# ### production scheduling 生产排程
# #### heuristic algorithm 启发式算法
#   quick but not optimal
# - GA(genetic algorithm) 遗传算法
#   - NSGA-II(non-dominated sorting genetic algorithm) 非支配排序遗传算法 II
#   <!-- - SPEA2(strength pareto evolutionary algorithm)
#   - 强度帕累托进化算法 II
#   - MOGA(multi-objective genetic algorithm)
#   - 多目标遗传算法
#   - IBEA(indicator-based evolutionary algorithm)
#   - 基于指标的进化算法
#   - PAES(pareto archived evolution strategy)
#   - 帕累托存档进化策略
#   - GDE3(generalized differential evolution)
#   - 广义差分进化算法
#   - MOEA/D(multi-objective evolutionary algorithm based on decomposition)
#   - 基于分解的多目标进化算法
#   - NSGA-III(non-dominated sorting genetic algorithm III)
#   - 非支配排序遗传算法 III
#   - MOEA/D-DE(multi-objective evolutionary algorithm based on decomposition with differential evolution)
#   - 基于差分进化分解的多目标进化算法
#   - MOEA/D-ACO(multi-objective evolutionary algorithm based on decomposition with ant colony optimization)
#   - 基于蚁群优化分解的多目标进化算法
#   - MOEA/D-PSO(multi-objective evolutionary algorithm based on decomposition with particle swarm optimization)
#   - 基于粒子群优化分解的多目标进化算法
#   - MOEA/D-SA(multi-objective evolutionary algorithm based on decomposition with simulated annealing)
#   - 基于模拟退火分解的多目标进化算法
#   - MOEA/D-TS(multi-objective evolutionary algorithm based on decomposition with tabu search)
#   - 基于禁忌搜索分解的多目标进化算法
#   - MOEA/D-DEPSO(multi-objective evolutionary algorithm based on decomposition with differential evolution particle swarm optimization)
#   - 基于差分进化粒子群优化分解的多目标进化算法
#   - PSODE(基于分解的多目标粒子群优化差分进化)
#   - MOEA/D-ACODE(基于分解的多目标蚁群差分进化)
#   - MOEA/D-SADE(基于分解的多目标模拟退火差分进化)
#   - MOEA/D-TSDE(基于分解的多目标禁忌搜索差分进化)
#   - MOEA/D-DEPSODE(基于分解的多目标差分进化粒子群优化差分进化)
#    -->
# - neighborhood search 邻域搜索
#   - SA(simulated annealing) 模拟退火
#   - TS(tabu search) 禁忌搜索
# <!-- - PSO(particle swarm optimization)
# - 粒子群优化
# - ACO(ant colony optimization)
# - 蚁群优化
# - IWO(invasive weed optimization)
# - 入侵杂草优化
# - ABC(artificial bee colony)
# - 人工蜂群
# - HS(harmony search)
# - 和谐搜索
# - GWO(grey wolf optimization)
# - 灰狼优化
# - CS(cuckoo search)
# - 布谷鸟搜索
# - FFA(firefly algorithm)
# - 萤火虫算法
# - WOA(whale optimization algorithm)
# - 鲸鱼优化算法
# - MFO(moth-flame optimization)
# - 蛾火焰优化
# - BAT(bat algorithm)
# - 蝙蝠算法
# - SSA(salp swarm algorithm)
# - 虾群算法
# - FPA(flower pollination algorithm)
# - 花朵传粉算法
# - MVO(multiverse optimization algorithm)
# - 多宇宙优化算法
# - LSHADE(local search based hybrid artificial development algorithm)
# - 基于局部搜索的混合人工开发算法
# - JADE(jade algorithm)
# - JADE算法
# - CLPSO(comprehensive learning particle swarm optimization)
# - 综合学习粒子群优化
# - DEPSO(differential evolution particle swarm optimization)
# - 差分进化粒子群优化
# - PSODE(psode algorithm)
# - psode 算法
# -->
#
# #### optimization algorithm 优化算法
# optimal but slow (NP-hard)
# - MIP(mixed integer programming) 混合整数规划
#   <!-- - LP(linear programming)
#   - 线性规划
#   - ILP(integer linear programming) -->
#   <!-- - 整数线性规划 -->
# - DP(dynamic programming)动态规划
# - BAB(branch and bound) 分支定界
# - Backtracking 回溯法 ?
#
# #### rule-based algorithm
# #### 基于规则的算法
# - FCFS(first come first serve) 先来先服务
# - SPT(shortest processing time) 最短处理时间
# - EDD(earliest due date) 最早DDL
# - LPT(longest processing time) 最长处理时间
# - CR(crirtical ratio) Priority Rule: 关键比率 优先规则：
#   by processing number, weight, ratio, due date, due date difference...
#   根据处理数量、权重、比率、到期日、到期日差异等
#   <!-- - S/OPN(sequencing by the order of processing number)
#   - 按处理数量排序
#   - S/OPW(sequencing by the order of processing weight)
#   - 按处理权重排序
#   - S/OPR(sequencing by the order of processing ratio)
#   - 按处理比率排序
#   - S/OPD(sequencing by the order of processing due date)
#   - 按处理到期日排序
#   - S/OPDD(sequencing by the order of processing due date difference)
#   - 按处理到期日差异排序 -->
#
# #### Neural Network 神经网络
#   Treat the scheduling problem as a plotting problem, and use the neural network to learn the mapping between the input and output.
#   将调度问题视为绘图问题，并使用神经网络学习输入和输出之间的映射。
#   - Diffusion Model 扩散模型
#   - Transformer Model Transformer 模型
#
#     MAE pre-training with fine-tuning
#     <!-- MAE 预训练与微调 -->
#     - Vision Transformer(ViT)
#     <!-- - 视觉Transformer -->
#     * Pixel Transformer(PiT)
#     <!-- - 像素Transformer -->
#   - RNN/MLP/LSTM... 循环神经网络/多层感知器/长短期记忆
# #### hybrid algorithm
# #### 混合算法
#
# ### production recommendation
# ### 生产推荐
# #### Inventory and Supply Chain Management Algorithms
# #### 库存和供应链管理算法
# - Network Flow 网络流
# - Economic Order Quantity 经济订货量
# - Reorder Point 重新排序点
# - Safety Stock 安全库存
#
# # 2. MES(manufacturing execution system) 执行系统/工单派发系统
#
# Integrate the MES system with the APS system to achieve real-time production scheduling and monitoring. 将 MES 系统与 APS 系统集成，实现实时生产调度和监控。
#
# APS =Forecasting and Planning=> MES =Scheduling and Monitoring=> Production Quality Control/Check=> Finished Product For APS/MES System to evaluate
# - (Plan Creation in APS) 在 APS 中创建计划
# - (Plan Transmission to MES) 计划传输到 MES
# - (Execution in MES) 在 MES 中执行
# - (Feedback to APS) 反馈至 APS
#
# ## Key Features
# - Real-time monitoring and tracking
# - Real-time scheduling and management
# - Real-time data collection and analysis
#
# ## Algorithm
# Similar to the planning part of APS system. The difference is that the MES system is more focused on the real-time scheduling and monitoring of the production process.
#
# Consider adding a dynamic dispatching algorithm to the MES system to improve the efficiency of the production process.(e.g. Random Forest, Neural Network, uber dispatching algorithm, etc.)
# 考虑在 MES 系统中加入动态调度算法，以提高生产过程的效率（如随机森林、神经网络、打车调度算法等）。

# %% [markdown]
# https://scholar.google.com/scholar?q=diffusion+model+for+planning+and+scheduling&hl=en&as_sdt=0&as_vis=1&oi=scholart | diffusion model for planning and scheduling - Google Scholar
# https://ir.library.oregonstate.edu/concern/graduate_thesis_or_dissertations/k0698f81q | Graduate Thesis Or Dissertation | Scheduling and Online Planning in Stochastic Diffusion Networks | ID: k0698f81q | ScholarsArchive@OSU
# https://dl.acm.org/doi/pdf/10.1145/3580305.3599412 | Learning to Schedule in Diffusion Probabilistic Models
# https://diffusion-planning.github.io/ | Diffuser: Reinforcement Learning with Diffusion Models
# https://arxiv.org/pdf/2205.09991 | 2205.09991
# https://github.com/jannerm/diffuser?tab=readme-ov-file | jannerm/diffuser: Code for the paper "Planning with Diffusion for Flexible Behavior Synthesis"
# https://www.google.com/search?q=job+planning+diffusion+model&rlz=1C1ONGR_enUS968US968&oq=job+planning+diffusion&gs_lcrp=EgZjaHJvbWUqBwgBECEYoAEyBggAEEUYOTIHCAEQIRigATIHCAIQIRigATIHCAMQIRigATIHCAQQIRigATIHCAUQIRifBdIBCDc3NzRqMGo3qAIAsAIA&sourceid=chrome&ie=UTF-8 | job planning diffusion model - Google Search
# https://github.com/opendilab/awesome-diffusion-model-in-rl | opendilab/awesome-diffusion-model-in-rl: A curated list of Diffusion Model in RL resources (continually updated)
# https://vis-www.cs.umass.edu/replandiffuser/ | Adaptive Online Replanning with Diffusion Models
# https://diffusion-planning.github.io/diffuser_icml2022.pdf | Planning with Diffusion for Flexible Behavior Synthesis
# https://www.google.com/search?q=diffusion+model+with+restrictions&rlz=1C1ONGR_enUS968US968&oq=diffusion+model+with+restrictions&gs_lcrp=EgZjaHJvbWUyCQgAEEUYORigATIHCAEQIRigATIHCAIQIRifBTIHCAMQIRifBdIBCTEyNjk0ajBqN6gCALACAA&sourceid=chrome&ie=UTF-8 | diffusion model with restrictions - Google Search
# https://arxiv.org/abs/2304.05364 | [2304.05364] Diffusion Models for Constrained Domains
# https://www.google.com/search?q=aps+for+Unrelated-machines+scheduling+with+ML&rlz=1C1ONGR_enUS968US968&oq=aps+for+Unrelated-machines+scheduling+with+ML&gs_lcrp=EgZjaHJvbWUyBggAEEUYOTIJCAEQIRgKGKABMgkIAhAhGAoYoAEyCQgDECEYChigATIJCAQQIRgKGKABMgcIBRAhGKsCMgcIBhAhGKsCMgcIBxAhGKsC0gEIOTY3NWowajeoAgCwAgA&sourceid=chrome&ie=UTF-8 | aps for Unrelated-machines scheduling with ML - Google Search
# https://www.sciencedirect.com/science/article/pii/S0305054822002428 | Unrelated parallel machine scheduling with multiple time windows: An application to earth observation satellite scheduling - ScienceDirect
# https://arxiv.org/abs/2402.18012 | [2402.18012] Diffusion Models as Constrained Samplers for Optimization with Unknown Constraints
# https://www.google.com/search?q=aps+software&rlz=1C1ONGR_enUS968US968&oq=aps+&gs_lcrp=EgZjaHJvbWUqBggBEEUYOzIGCAAQRRg5MgYIARBFGDsyBggCEEUYOzIGCAMQRRg7MgYIBBBFGDwyBggFEEUYPDIGCAYQRRg8MgYIBxBFGDzSAQgyMzc0ajBqN6gCALACAA&sourceid=chrome&ie=UTF-8 | aps software - Google Search
# https://apspayroll.com/solutions-for-your-industry/all-industries/?qgad=652096256121&qgterm=aps&utm_term=aps&utm_campaign=Branded&utm_source=adwords&utm_medium=ppc&hsa_acc=3847719824&hsa_cam=19872268453&hsa_grp=150178771831&hsa_ad=652096256121&hsa_src=g&hsa_tgt=kwd-87792634&hsa_kw=aps&hsa_mt=p&hsa_net=adwords&hsa_ver=3&gad_source=1&gclid=CjwKCAjwg8qzBhAoEiwAWagLrNAy_MoakYedWVOCN2Yc2HPlDPBb0G13-BI0h3huh1sVFR2U5SR7XRoCArYQAvD_BwE | Payroll and HR Solutions for All Industries - APS Payroll
# https://www.capterra.com/sem-compare/accounts-payable-software/?utm_source=ps-google&utm_medium=ppc&utm_campaign=:1:CAP:2:COM:3:All:4:US:5:BAU:6:SOF:7:Desktop:8:BR:9:Accounts_Payable&network=g&gclid=CjwKCAjwg8qzBhAoEiwAWagLrFwqXsXOAU9ixYXnOjaj8o78EDYqbUerwhqzVaL4NT2-zBego_vSPBoCttoQAvD_BwE | AP Software - Review Leading Systems
# https://aps.software/account/login?ReturnUrl=%2F | APS
# https://www.sw.siemens.com/en-US/technology/advanced-planning-scheduling-aps/ | Advanced Planning and Scheduling | Siemens Software
# https://www.google.com/search?q=planettogether&rlz=1C1ONGR_enUS968US968&oq=planettogether&gs_lcrp=EgZjaHJvbWUyBggAEEUYOTIWCAEQLhiDARjHARixAxjJAxjRAxiABDINCAIQLhjUAhixAxiABDINCAMQLhjUAhixAxiABDINCAQQLhjUAhixAxiABDIHCAUQLhiABDIHCAYQABiABDINCAcQABiDARixAxiABDINCAgQABiSAxiABBiKBdIBCDQzNzNqMGo3qAIAsAIA&sourceid=chrome&ie=UTF-8 | planettogether - Google Search
# https://github.com/ocatias/Metaheuristic-UPMS | ocatias/Metaheuristic-UPMS: Compute schedules for parallel machines with mixed integer programing, simulated annealing and very large neighborhood search algorithms.
# https://sarem-seitz.com/posts/forecasting-with-decision-trees-and-random-forests/ | Forecasting with Decision Trees and Random Forests - Sarem Seitz
# https://link.springer.com/article/10.1007/s12530-024-09586-5 | An improved K-means clustering and optimal random forest for scheduling workloads in virtual servers | Evolving Systems
# https://www.tandfonline.com/doi/full/10.1080/00207543.2019.1581954 | Full article: Learning dispatching rules using random forest in flexible job shop scheduling problems
# https://github.com/Lei-Kun/End-to-end-DRL-for-FJSP | Lei-Kun/End-to-end-DRL-for-FJSP: This is the official code of the publised paper 'A Multi-action Deep Reinforcement Learning Framework for Flexible Job-shop Scheduling Problem'
# https://github.com/Lei-Kun/Dispatching-rules-for-FJSP?tab=readme-ov-file | Lei-Kun/Dispatching-rules-for-FJSP: This is the official code for the baseline methods of the publised paper 'A Multi-action Deep Reinforcement Learning Framework for Flexible Job-shop Scheduling Problem'
# https://github.com/Lei-Kun/FJSP-benchmarks?tab=readme-ov-file | Lei-Kun/FJSP-benchmarks: The public benchmark instances of flexible job shop scheduling problem
# https://www.sciencedirect.com/science/article/pii/S0957417422010624 | A multi-action deep reinforcement learning framework for flexible Job-shop scheduling problem - ScienceDirect
# http://www.shodor.org/petascale/materials/UPModules/dynamicProgrammingPartI/ | Petascale : Dynamic Programming with CUDA, Part I
# https://www.google.com/search?q=parallel+dynamic+programming&newwindow=1&sca_esv=5f1d5a2af2a99c51&rlz=1C1ONGR_enUS968US968&sxsrf=ADLYWIJ2bR3JBBbMtS7zvs_9_Fm6ZcGqOg%3A1718612344915&ei=ePFvZpnIN9jIkPIP7o6IyA8&ved=0ahUKEwiZ5MzymeKGAxVYJEQIHW4HAvkQ4dUDCBA&uact=5&oq=parallel+dynamic+programming&gs_lp=Egxnd3Mtd2l6LXNlcnAiHHBhcmFsbGVsIGR5bmFtaWMgcHJvZ3JhbW1pbmdIjApQAFjACHAAeAGQAQCYAZUDoAG9DqoBBTMtNC4xuAEDyAEA-AEBmAIAoAIAmAMAkgcAoAfZJw&sclient=gws-wiz-serp | parallel dynamic programming - Google Search
# https://towardsdatascience.com/gpu-optimized-dynamic-programming-8d5ba3d7064f | GPU Optimized dynamic programming | by Anuradha Wickramarachchi | Towards Data Science
# https://www.cs.hiroshima-u.ac.jp/cs/_media/triangulation_ieice.pdf | triangulation_ieice.pdf
# https://ieeexplore.ieee.org/abstract/document/8847177 | Optimizing Order Dispatch for Ride-Sharing Systems | IEEE Conference Publication | IEEE Xplore
# https://scholar.google.com/scholar?hl=en&as_sdt=0%2C5&q=uber+order+dispatching&btnG=&oq=uber+order+dispa | uber order dispatching - Google Scholar
# https://www.leewayhertz.com/ai-in-production-planning/#overview-production-planning | AI for production planning: Significance, use cases, benefits, technologies and development
# https://medium.com/analytics-vidhya/how-to-train-ms-pacman-with-reinforcement-learning-dea714a2365e | How to Train Ms-Pacman with Reinforcement Learning | by Jose Alberto Leyva Contreras | Analytics Vidhya | Medium
# https://scholar.google.com/scholar?hl=en&as_sdt=0%2C5&q=Manufacturing+operations+management&btnG= | Manufacturing operations management - Google Scholar
# https://github.com/srinadhu/RL_Pacman | srinadhu/RL_Pacman: Reinforcement Learning in Pacman
# http://incompleteideas.net/book/RLbook2020.pdf | incompleteideas.net/book/RLbook2020.pdf
# https://arxiv.org/pdf/1312.5602 | 1312.5602
# https://jalammar.github.io/illustrated-stable-diffusion/ | The Illustrated Stable Diffusion – Jay Alammar – Visualizing machine learning one concept at a time.
# https://www.google.com/search?q=mixed+integer+programming+vs+dynamic+programming+time+complexity&rlz=1C1ONGR_enUS968US968&oq=mixed+integer+programming+vs+dynamic+programming+time+complexity&gs_lcrp=EgZjaHJvbWUyBggAEEUYOdIBCTIxMDIyajBqN6gCALACAA&sourceid=chrome&ie=UTF-8 | mixed integer programming vs dynamic programming time complexity - Google Search
# https://publik.tuwien.ac.at/files/publik_290438.pdf | A comparison between mixed-integer linear programming and dynamic programming with state prediction as novelty for solving unit commitment
# https://arxiv.org/pdf/2402.15194 | Fine-Tuning of Continuous-Time Diffusion Models as Entropy-Regularized Control
# https://en.wikipedia.org/wiki/U-Net | U-Net - Wikipedia
# https://www.google.com/search?q=unet+diffusion&newwindow=1&sca_esv=3fd026c1a73d8e9b&rlz=1C1ONGR_enUS968US968&sxsrf=ADLYWILB6hj8rGFPI5TIsFRcMQ4eFEUxBg%3A1718353484824&ei=TP5rZraAMqfYkPIP4c-moAc&ved=0ahUKEwi21r7I1dqGAxUnLEQIHeGnCXQQ4dUDCBA&uact=5&oq=unet+diffusion&gs_lp=&sclient=gws-wiz-serp | unet diffusion - Google Search
# https://www.google.com/search?q=diffusion+model+for+planning&rlz=1C1ONGR_enUS968US968&oq=diffusion+model+for+planning&gs_lcrp=EgZjaHJvbWUyCQgAEEUYORiABDIICAEQABgWGB4yCAgCEAAYFhgeMgoIAxAAGA8YFhgeMg0IBBAAGIYDGIAEGIoFMg0IBRAAGIYDGIAEGIoFMg0IBhAAGIYDGIAEGIoFMg0IBxAAGIYDGIAEGIoFMgoICBAAGIAEGKIEMgoICRAAGIAEGKIE0gEJMjEzMjZqMGo3qAIAsAIA&sourceid=chrome&ie=UTF-8 | diffusion model for planning - Google Search
# https://www.google.com/search?q=diffusion+model+for+planning+and+schedulingg&rlz=1C1ONGR_enUS968US968&oq=diffusion+model+for+planning+and+schedulingg&gs_lcrp=EgZjaHJvbWUyBggAEEUYOTIHCAEQIRigATIHCAIQIRigATIHCAMQIRigAdIBCTI5ODM4ajBqN6gCALACAA&sourceid=chrome&ie=UTF-8 | diffusion model for planning and schedulingg - Google Search
# chrome://history/grouped?q=snic+solution | History
# https://ibmdecisionoptimization.github.io/docplex-doc/cp/_modules/docplex/cp/config.html | docplex.cp.config — DOcplex.CP: Constraint Programming Modeling for Python V2.25 documentation
# https://stackoverflow.com/questions/59054559/cpoexception-can-not-execute-command-cpoptimizer-angel-please-check-availab | optimization - CpoException: Can not execute command 'cpoptimizer -angel'. Please check availability of required executable file - Stack Overflow
# https://bjbas.springeropen.com/articles/10.1186/s43088-023-00460-y | Machine learning-driven optimization of enterprise resource planning (ERP) systems: a comprehensive review | Beni-Suef University Journal of Basic and Applied Sciences | Full Text
# https://dl.acm.org/doi/abs/10.14778/3204028.3204030 | Order dispatch in price-aware ridesharing | Proceedings of the VLDB Endowment
# https://www.leewayhertz.com/ai-in-production-planning/#challenges-ai-addresses | AI for production planning: Significance, use cases, benefits, technologies and development
# https://machinelearningmastery.com/simulated-annealing-from-scratch-in-python/ | Simulated Annealing From Scratch in Python - MachineLearningMastery.com
# https://www.google.com/search?q=erp+with+reinforcement+learning&newwindow=1&sca_esv=5f295d922f4ac677&rlz=1C1ONGR_enUS968US968&sxsrf=ADLYWII7w4OeFheLCXgzamINYBDn3bpXGQ%3A1718681727961&ei=fwBxZq6tOs3fkPIPraC52AU&oq=erp+with+reinf&gs_lp=...&sclient=gws-wiz-serp | erp with reinforcement learning - Google Search
# https://scholar.google.com/scholar?hl=en&as_sdt=0%2C5&q=industry+4.0+manufacturing+execution+system&btnG=&oq=ml+in+Manufacturing+Execution+System | industry 4.0 manufacturing execution system - Google Scholar
# https://api.repository.cam.ac.uk/server/api/core/bitstreams/436c9fd5-629c-4227-abec-1e7d146afcf4/content | content
# https://www.sciencedirect.com/science/article/pii/S2351978919301155 | An Overview of Next-generation Manufacturing Execution Systems: How important is MES for Industry 4.0? - ScienceDirect
# https://www.google.com/search?q=dynamic+programming+for+unrelated+scheduling&newwindow=1&sca_esv=3fd026c1a73d8e9b&rlz=1C1ONGR_enUS968US968&sxsrf=ADLYWII_tQ0wZvXs_PS4C1RBo9QpulDexQ%3A1718354851331&ei=owNsZuL3E4zAkPIP1aGWsAU&oq=dynamic+programming+for+unrelated+&gs_lp=Egxnd3Mtd2l6LXNlcnAiImR5bmFtaWMgcHJvZ3JhbW1pbmcgZm9yIHVucmVsYXRlZCAqAggAMgUQIRigATIFECEYoAEyBRAhGKABMgUQIRirAkj7RVCyBVi-NXADeAGQAQOYAYEGoAHfN6oBCjMtMTQuMS4wLjK4AQPIAQD4AQGYAhGgAqspwgIKEAAYsAMY1gQYR8ICCxAAGIAEGJECGIoFwgIFEAAYgATCAgoQABiABBhDGIoFwgIFEC4YgATCAgYQABgWGB7CAggQABgWGB4YD8ICCxAAGIAEGIYDGIoFwgIIEAAYgAQYogTCAgcQIRigARgKwgIEECEYCpgDAIgGAZAGCJIHCDMuMy0xMy4xoAevdA&sclient=gws-wiz-serp | dynamic programming for unrelated scheduling - Google Search
# https://www.sciencedirect.com/science/article/pii/S240589631631117X?ref=pdf_download&fr=RR-2&rr=89600d4acb492f38 | Efficient Approaches to Scheduling for Unrelated Parallel Machines with Release Dates - ScienceDirect
# https://www.sciencedirect.com/science/article/pii/S240589631631117X?ref=pdf_download&fr=RR-2&rr=8971b6de6c917cd7 | Efficient Approaches to Scheduling for Unrelated Parallel Machines with Release Dates - ScienceDirect
# https://www.sciencedirect.com/science/article/pii/S0377221721010973?ref=pdf_download&fr=RR-2&rr=89613ac82e962ef1 | Approximate dynamic programming for an energy-efficient parallel machine scheduling problem - ScienceDirect
# https://www.google.com/search?q=dynamic+programming+for+unrelated+scheduling+github&newwindow=1&sca_esv=4e2a714bc4107f31&rlz=1C1ONGR_enUS968US968&sxsrf=ADLYWIJ4DbYoS1OFfmENUBzSFv6KWivtOw%3A1718590077244&ei=fZpvZo3JDpHFkPIP84OMuAU&ved=0ahUKEwjN-8X4xuGGAxWRIkQIHfMBA1cQ4dUDCBE&uact=5&oq=dynamic+programming+for+unrelated+scheduling+github&gs_lp=Egxnd3Mtd2l6LXNlcnAiM2R5bmFtaWMgcHJvZ3JhbW1pbmcgZm9yIHVucmVsYXRlZCBzY2hlZHVsaW5nIGdpdGh1YjIFECEYoAEyBRAhGKABSOsPUOYEWN8OcAF4AZABAJgB0wKgAcoPqgEDMy02uAEDyAEA-AEBmAIHoALdD8ICChAAGLADGNYEGEfCAgUQIRirApgDAIgGAZAGCJIHBTEuMy02oAfRHQ&sclient=gws-wiz-serp | dynamic programming for unrelated scheduling github - Google Search
# https://ojmo.centre-mersenne.org/item/10.5802/ojmo.4.pdf | Exact makespan minimization of unrelated parallel machines
# https://scholar.google.com/scholar?start=10&q=reinforcement+learning+on+schedule+planning&hl=en&as_sdt=0,5 | reinforcement learning on schedule planning - Google Scholar
# https://www.sciencedirect.com/science/article/pii/S0926580521005203?ref=pdf_download&fr=RR-2&rr=895f83057a6a0ff8 | Automating look-ahead schedule generation for construction using linked-data based constraint checking and reinforcement learning - ScienceDirect
# https://repository.rit.edu/cgi/viewcontent.cgi?article=11536&context=theses | Efficient Algorithms for Unrelated Parallel Machine Scheduling Considering Time of Use Pricing and Demand Charges
# https://www.google.com/search?q=diffusion+model+for+gantt+plot&newwindow=1&sca_esv=ea1f1f1586db5291&rlz=1C1ONGR_enUS968US968&biw=1536&bih=738&sxsrf=ADLYWILFOzw2j7ecKuLj7QI_-WXtmBeU6g%3A1718704128156&ei=AFhxZvicCdjbkPIPiNidsAk&ved=0ahUKEwj4nKHo7-SGAxXYLUQIHQhsB5YQ4dUDCBA&uact=5&oq=diffusion+model+for+gantt+plot&gs_lp=Egxnd3Mtd2l6LXNlcnAiHmRpZmZ1c2lvbiBtb2RlbCBmb3IgZ2FudHQgcGxvdDIIEAAYgAQYogQyCBAAGIAEGKIEMggQABiABBiiBDIIEAAYgAQYogRItTNQvQhYxDJwA3gBkAECmAGxBKABtTyqAQgzLTE2LjMuMbgBA8gBAPgBAZgCBqAC_gjCAgoQABiwAxjWBBhHwgINEAAYgAQYsAMYQxiKBcICBxAAGIAEGA3CAggQABgFGA0YHsICCBAAGAgYDRgewgIMEAAYBRgKGA0YHhgPwgILEAAYgAQYhgMYigXCAggQIRigARjDBJgDAIgGAZAGCZIHBzMuMy0yLjGgB9db&sclient=gws-wiz-serp | diffusion model for gantt plot - Google Search
# https://scholar.google.com/scholar?hl=en&as_sdt=0%2C5&as_vis=1&q=advance+planning+and+scheduling+gantt+plot&btnG= | advance planning and scheduling gantt plot - Google Scholar
# https://www.ijasret.com/VolumeArticles/FullTextPDF/926_56.TO_STUDY_ADVANCED_PROJECT_PLANNING_AND_SCHEDULING-CASE_STUDY.pdf | 503 Service Temporarily Unavailable
# https://aiche.onlinelibrary.wiley.com/doi/full/10.1002/aic.11970 | Recipe determination and scheduling of gasoline blending operations - Li - 2010 - AIChE Journal - Wiley Online Library
# https://www.geeksforgeeks.org/introduction-to-branch-and-bound-data-structures-and-algorithms-tutorial/ | Introduction to Branch and Bound - Data Structures and Algorithms Tutorial - GeeksforGeeks
# https://arxiv.org/pdf/2006.08327 | 2006.08327
# https://ieeexplore.ieee.org/document/6298160 | Two Sides of a Coin: Optimizing the Schedule of MapReduce Jobs to Minimize Their Makespan and Improve Cluster Performance | IEEE Conference Publication | IEEE Xplore
# https://www.cs.jhu.edu/~mdinitz/classes/ApproxAlgorithms/Spring2019/Lectures/lecture8.pdf | lecture8.pdf
# https://www.bing.com/search?q=knapsack+with+multiple+bags&qs=n&form=QBRE&sp=-1&lq=0&pq=knapsack+with+multiple+bags&sc=10-27&sk=&cvid=45FCF22CCCA54DAD894EE7D0511E9C88&ghsh=0&ghacc=0&ghpl=&mkt=zh-CN | knapsack with multiple bags - Search
# https://cs.stackexchange.com/questions/77026/multiple-knapsack-using-dynamic-programming | np complete - Multiple Knapsack using Dynamic Programming - Computer Science Stack Exchange
# https://www.geeksforgeeks.org/double-knapsack-dynamic-programming/ | Double Knapsack | Dynamic Programming - GeeksforGeeks

# %% [markdown]
# https://dl.acm.org/doi/abs/10.1145/3308558.3313464 | Alleviating Users' Pain of Waiting: Effective Task Grouping for Online-to-Offline Food Delivery Services | The World Wide Web Conference
# file:///C:/Users/Yuyang-RPI/Downloads/3308558.3313464.pdf | Alleviating Users' Pain of Waiting: Effective Task Grouping for Online-to-Offline Food Delivery Services
# https://link.springer.com/article/10.1186/s12960-021-00637-5#Sec2 | Task-sharing to support paediatric and child health service delivery in low- and middle-income countries: current practice and a scoping review of emerging opportunities | Human Resources for Health
# https://www.google.com/search?q=DRL4Route+github&rlz=1C1ONGR_enUS968US968&oq=DRL4Route+github&gs_lcrp=EgZjaHJvbWUyBggAEEUYOTIKCAEQABgKGA0YHjIKCAIQABgIGA0YHjINCAMQABiGAxiABBiKBTIKCAQQABiABBiiBDIKCAUQABiABBiiBDIKCAYQABiABBiiBDIKCAcQABiABBiiBDIKCAgQABiABBiiBNIBCDUxODRqMGo3qAIAsAIA&sourceid=chrome&ie=UTF-8 | DRL4Route github - Google Search
# https://github.com/maoxiaowei97/DRL4Route | maoxiaowei97/DRL4Route
# https://github.com/frePPLe/frepple/releases/tag/9.0.0 | Release 9.0.0 Community Edition · frePPLe/frepple
# https://faculty.tuck.dartmouth.edu/images/uploads/faculty/principles-sequencing-scheduling/TardinessIntegerProgramming.pdf | IP SEQUENCING
# https://dl.acm.org/doi/pdf/10.1145/321941.321951 | Exact and Approximate Algorithms for Scheduling Nonidentical Processors
# http://i.stanford.edu/pub/cstr/reports/cs/tr/98/1611/CS-TR-98-1611.pdf | thesis.dvi
# https://www.semanticscholar.org/paper/Exact-and-Approximate-Algorithms-for-Scheduling-Horowitz-Sahni/d4b0b8e6063ee53098d5677a5c5daa46de1a478e#related-papers | Exact and Approximate Algorithms for Scheduling Nonidentical Processors | Semantic Scholar
# https://www.semanticscholar.org/paper/Scheduling-Multiprocessor-Tasks-with-Genetic-Golub-Kasapovic/e16e539e8b8c0718c8bd5c46f15eadd92345e25f | [PDF] Scheduling Multiprocessor Tasks with Genetic Algorithms | Semantic Scholar
# https://towardsdatascience.com/the-job-shop-scheduling-problem-mixed-integer-programming-models-4bbee83d16ab | The Job-Shop Scheduling Problem: Mixed-Integer Programming Models | by Bruno Scalia C. F. Leite | Towards Data Science

# %% [markdown]
# # 1. APS(advanced planning and scheduling)
#
# ## demand
# - Continuous Process Manufacturing
# - Discrete Manufacturing
#
# ## problems
# ### (Job) Shop Scheduling Problem(JSSP)
# ### Resource-Constrained Project Scheduling Problem(RCPSP)
# ### Makespan Minimization Problem(MMP)
# ### Total Weighted Tardiness Problem(TWTP)
# ### Minimizing Other Objectives(e.g cost, energy, etc.)
#
# ## places need algorithms
# Noticing these are all NP-hard problems, we need to use heuristic algorithms to solve large-scale problems(e.g. 6 machines, 12 jobs).
#
# ### production planning (Forecasting)
# - ARIMA(autoregressive integrated moving average)
#   - SARIMA(seasonal autoregressive integrated moving average)
#   - ARIMAX(autoregressive integrated moving average with exogenous variables)
# - ETS(exponential smoothing)
#   <!-- - ETSX(error, trend, seasonality with exogenous variables) -->
# - Neural Network
#   - MLP(multi-layer perceptron)
#   - LSTM(long short-term memory)
# - Random Forest
#
# ### production scheduling
# #### heuristic algorithm
# - GA(genetic algorithm)
#   - NSGA-II(non-dominated sorting genetic algorithm)
#   <!-- - SPEA2(strength pareto evolutionary algorithm)
#   - MOGA(multi-objective genetic algorithm)
#   - IBEA(indicator-based evolutionary algorithm)
#   - PAES(pareto archived evolution strategy)
#   - GDE3(generalized differential evolution)
#   - MOEA/D(multi-objective evolutionary algorithm based on decomposition)
#   - NSGA-III(non-dominated sorting genetic algorithm III)
#   - MOEA/D-DE(multi-objective evolutionary algorithm based on decomposition with differential evolution)
#   - MOEA/D-ACO(multi-objective evolutionary algorithm based on decomposition with ant colony optimization)
#   - MOEA/D-PSO(multi-objective evolutionary algorithm based on decomposition with particle swarm optimization)
#   - MOEA/D-SA(multi-objective evolutionary algorithm based on decomposition with simulated annealing)
#   - MOEA/D-TS(multi-objective evolutionary algorithm based on decomposition with tabu search)
#   - MOEA/D-DEPSO(multi-objective evolutionary algorithm based on decomposition with differential evolution particle swarm optimization)
#   - MOEA/D-PSODE(multi-objective evolutionary algorithm based on decomposition with particle swarm optimization differential evolution)
#   - MOEA/D-ACODE(multi-objective evolutionary algorithm based on decomposition with ant colony optimization differential evolution)
#   - MOEA/D-SADE(multi-objective evolutionary algorithm based on decomposition with simulated annealing differential evolution)
#   - MOEA/D-TSDE(multi-objective evolutionary algorithm based on decomposition with tabu search differential evolution)
#   - MOEA/D-DEPSODE(multi-objective evolutionary algorithm based on decomposition with differential evolution particle swarm optimization differential evolution)
#    -->
# - SA(simulated annealing)
# - neighborhood search
#   - TS(tabu search) quick but not optimal
# <!-- - PSO(particle swarm optimization)
# - ACO(ant colony optimization)
# - IWO(invasive weed optimization)
# - ABC(artificial bee colony)
# - HS(harmony search)
# - GWO(grey wolf optimization)
# - CS(cuckoo search)
# - FFA(firefly algorithm)
# - WOA(whale optimization algorithm)
# - MFO(moth-flame optimization)
# - BAT(bat algorithm)
# - SSA(salp swarm algorithm)
# - FPA(flower pollination algorithm)
# - MVO(multiverse optimization algorithm)
# - LSHADE(local search based hybrid artificial development algorithm)
# - JADE(jade algorithm)
# - CLPSO(comprehensive learning particle swarm optimization)
# - DEPSO(differential evolution particle swarm optimization)
# - PSODE(psode algorithm)
# -->
#
# #### optimization algorithm
# - MIP(mixed integer programming)
#   <!-- - LP(linear programming)
#   - ILP(integer linear programming) -->
# - DP(dynamic programming)
# - BAB(branch and bound) optimal but slow
#   - Backtracking ?
# #### rule-based algorithm
# - FCFS(first come first serve)
# - SPT(shortest processing time)
# - EDD(earliest due date)
# - LPT(longest processing time)
# - CR(crirtical ratio) Priority Rule:
#   by processing number, weight, ratio, due date, due date difference...
#   <!-- - S/OPN(sequencing by the order of processing number)
#   - S/OPW(sequencing by the order of processing weight)
#   - S/OPR(sequencing by the order of processing ratio)
#   - S/OPD(sequencing by the order of processing due date)
#   - S/OPDD(sequencing by the order of processing due date difference) -->
#
# #### Neural Network
#   Treat the scheduling problem as a ploting problem, and use the neural network to learn the mapping between the input and output.
#   - Diffusion Model
#   - Transformer Model
#     MAE pre-training with fine-tuning
#     - Vision Transformer(ViT)
#     * Pixel Transformer(PiT)
#   - RNN/MLP/LSTM...
# #### hybrid algorithm
#
# ### production recommendation
# #### Inventory and Supply Chain Management Algorithms
# - Network Flow
# - Economic Order Quantity
# - Reorder Point
# - Safety Stock
#
#
# # 2. MES(manufacturing execution system)
#
# Integrate the MES system with the APS system to achieve real-time production scheduling and monitoring.
#
# APS =Forecasting and Planning=> MES =Scheduling and Monitoring=> Production Quality Control/Check=> Finished Product For APS/MES System to evaluate
# - (Plan Creation in APS)
# - (Plan Transmission to MES)
# - (Execution in MES)
# - (Feedback to APS)
#
#
#
# ## Key Features
# - Real-time monitoring and tracking
# - Real-time scheduling and management
# - Real-time data collection and analysis
#
# ## Algorithm
# Similar to the planning part of APS system. The difference is that the MES system is more focused on the real-time scheduling and monitoring of the production process.
#
# Consider adding a dynamic dispatching algorithm to the MES system to improve the efficiency of the production process.(e.g. Random Forest, Neural Network, uber dispatching algorithm, etc.)

# %% [markdown]
# # Simulated annealing (SA)
#
# Let s = s0
# For k = 0 through kmax (exclusive):
# T ← temperature( 1 - (k+1)/kmax )
# Pick a random neighbour, snew ← neighbour(s)
# If P(E(s), E(snew), T) ≥ random(0, 1):
# s ← snew
# Output: the final state s
# <!-- ![sth](https://en.wikipedia.org/wiki/File:3D_TSP_solved_with_simulated_annealing_2.5_MB.gif) -->
